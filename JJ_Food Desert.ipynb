# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
# !pip install pivottablejs
# Out:
# Requirement already satisfied: pivottablejs in c:\users\john jenkins\anaconda3\lib\site-packages
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
desert_csv = "Food Desert_Data_jj.csv"

# %%
desert_csv_df = pd.read_csv(desert_csv)

# %%
#from pivottablejs import pivot_ui
#pivot_ui(desert_csv_df)

# %%
desert_csv_df.head()
# Out:
#   State   Region            Division County Name  Grocery 2009  \
# 0    AL    South  East South Central       Coosa             0
# 1    AK     West             Pacific  Dillingham             5
# 2    CO     West            Mountain     Mineral             1
# 3    GA    South      South Atlantic       Irwin             1
# 4    IA  Midwest  West North Central     Audubon             2
#
#    Convenience 2009  Fast Food Restaurants 2009  Adult Diabetes % 2009  \
# 0                 9                           0                   15.1
# 1                 2                           0                    8.2
# 2                 0                           0                    6.9
# 3                 6                           0                   11.7
# 4                 3                           0                   10.4
#
#    Adult Obsesity % 2009  Median Household Income 2009         ...          \
# 0                   33.8                         33721         ...
# 1                   34.2                         46845         ...
# 2                   19.0                         45645         ...
# 3                   31.2                         32859         ...
# 4                   33.2                         45563         ...
#
#    Population 2014  FF per capita 2009  FF per capita 2014  \
# 0            10794                 0.0             0.00009
# 1             4989                 0.0             0.00020
# 2              693                 0.0             0.00144
# 3             9133                 0.0             0.00044
# 4             5785                 0.0             0.00017
#
#    % change FF Per Capita  Grocery per capita 2009  Grocery per capita 2014  \
# 0                    0.01                 0.000000                 0.000093
# 1                    0.02                 0.001032                 0.001203
# 2                    0.14                 0.001404                 0.001443
# 3                    0.04                 0.000105                 0.000109
# 4                    0.02                 0.000327                 0.000173
#
#    % change in grocery per capita  % change in Access  % Change in Obesity  \
# 0                            0.00                0.00                17.46
# 1                           16.58               54.55                11.11
# 2                            2.74              -86.46                -4.74
# 3                            4.43                0.00                -6.41
# 4                          -47.11              100.00                -6.02
#
#    % change in income
# 0                6.99
# 1                8.34
# 2               10.59
# 3                7.38
# 4               11.82
#
# [5 rows x 31 columns]

# %%
desert_csv_df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County Name', 'Grocery 2009',
#        'Convenience 2009', 'Fast Food Restaurants 2009',
#        'Adult Diabetes % 2009', 'Adult Obsesity % 2009',
#        'Median Household Income 2009', 'Limited Access Population% 2009',
#        'Limited Access Population 2009', 'Population 2009', 'Grocery 2014',
#        'Convenience 2014', 'Fast Food Restaurants 2014', 'Adult Diabetes 2014',
#        'Adult Obesity 2014', 'Median Household Income 2014',
#        'Limited Access % 2014', 'Limited Access 2014', 'Population 2014',
#        'FF per capita 2009', 'FF per capita 2014', '% change FF Per Capita',
#        'Grocery per capita 2009', 'Grocery per capita 2014',
#        '% change in grocery per capita', '% change in Access',
#        '% Change in Obesity', '% change in income'],
#       dtype='object')

# %%
x_axis = desert_csv_df['Median Household Income 2009']

y_axis = desert_csv_df['Adult Diabetes % 2009']

# %%
#low access vs. diabetes

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
plt.title("Diabetes vs Median Household Income 2009")
plt.xlabel("Median Household Income")
plt.ylabel("Adult Diabetes % 2009")

#plot grid
#plt.grid(True, color='w', linestyle='-', linewidth=.5)
#plt.gca().patch.set_facecolor('0.85')

plt.show()

# %%
x2_axis = desert_csv_df['Median Household Income 2009']

y2_axis = desert_csv_df['Adult Obsesity % 2009']

# %%
#low access vs. diabetes

plt.scatter(x2_axis, y2_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.5)
#plt.title("Diabetes vs Limited Access")
#plt.xlabel("Limited Access")
#plt.ylabel("Adult Diabetes % ")

#plot grid
plt.grid(True, color='w', linestyle='-', linewidth=.2)
plt.gca().patch.set_facecolor('0.85')

plt.show()

# %%
new_df = desert_csv_df[desert_csv_df['State']=='TX']
new_df.head()
# Out:
#    State County Name  Grocery 2009  Convenience 2009  \
# 34    TX     Cameron             4                 5
# 35    TX    Comanche             2                 1
# 36    TX       Crane             1                 4
# 37    TX   Glasscock             0                 1
# 38    TX     Haskell             1                 3
#
#     Fast Food Restaurants 2009  Adult Diabetes % 2009  Adult Obsesity % 2009  \
# 34                           0                   10.6                   32.9
# 35                           0                   10.3                   28.9
# 36                           0                   10.3                   30.1
# 37                           0                   10.0                   29.0
# 38                           0                   10.1                   30.7
#
#     Median Household Income 2009  Limited Access Population% 2009  \
# 34                         47100                               25
# 35                         38207                               18
# 36                         50356                                9
# 37                         54354                               98
# 38                         51257                              100
#
#     Limited Access Population 2009         ...          Population 2014  \
# 34                            1681         ...                     6697
# 35                             337         ...                     1945
# 36                             389         ...                     4928
# 37                            1204         ...                     1297
# 38                            4256         ...                     4076
#
#     FF per capita 2009  FF per capita 2014  % change FF Per Capita  \
# 34                 0.0             0.00015                    0.01
# 35                 0.0             0.00051                    0.05
# 36                 0.0             0.00061                    0.06
# 37                 0.0             0.00077                    0.08
# 38                 0.0             0.00025                    0.02
#
#     Grocery per capita 2009  Grocery per capita 2014  \
# 34                 0.000585                 0.000448
# 35                 0.001058                 0.001028
# 36                 0.000229                 0.000203
# 37                 0.000000                 0.000000
# 38                 0.000235                 0.000491
#
#     % change in grocery per capita  % change in Access  % Change in Obesity  \
# 34                     -23.4097357                   4                -4.26
# 35                    -2.776349614                   0                16.26
# 36                    -11.22159091                   0                -2.66
# 37                         #DIV/0!                   0                -7.59
# 38                     108.8321884                   0                10.42
#
#     % change in income
# 34               19.45
# 35               14.66
# 36               30.83
# 37               37.72
# 38               15.80
#
# [5 rows x 29 columns]

# %%
#x3_axis = desert_csv_df['Limited Access Population% 2009']

y3_axis = new_df['Adult Obesity 2014']

x3_axis = new_df['Median Household Income 2014']

#y3_axis = desert_csv_df['Adult Obesity 2014']

#x3_axis = desert_csv_df['Limited Access % 2014']

# %%
#low access vs. diabetes

plt.scatter(x3_axis, y3_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.4)
#plt.title("Diabetes vs Limited Access")
#plt.xlabel("Limited Access")
#plt.ylabel("Adult Diabetes % ")

#plot grid
plt.grid(True, color='w', linestyle='-', linewidth=.2)
plt.gca().patch.set_facecolor('0.85')

#plt.xlim(-10,100)
#plt.ylim(-10,10)

plt.show()

# %%
desert_csv_df.columns
# Out:
# Index(['State', 'County Name', 'Grocery 2009', 'Convenience 2009',
#        'Fast Food Restaurants 2009', 'Adult Diabetes % 2009',
#        'Adult Obsesity % 2009', 'Median Household Income 2009',
#        'Limited Access Population% 2009', 'Limited Access Population 2009',
#        'Population 2009', 'Grocery 2014', 'Convenience 2014',
#        'Fast Food Restaurants 2014', 'Adult Diabetes 2014',
#        'Adult Obesity 2014', 'Median Household Income 2014',
#        'Limited Access % 2014', 'Limited Access 2014', 'Population 2014',
#        'FF per capita 2009', 'FF per capita 2014', '% change FF Per Capita',
#        'Grocery per capita 2009', 'Grocery per capita 2014',
#        '% change in grocery per capita', '% change in Access',
#        '% Change in Obesity', '% change in income'],
#       dtype='object')

# %%
x5 = desert_csv_df.groupby('State')[['Adult Obsesity % 2009']].mean()

y5 = desert_csv_df.groupby('State')[['Limited Access Population 2009']].mean()


plt.scatter(x5, y5, marker="o", facecolors="blue", edgecolors="black", alpha=0.4)

#plot grid
#plt.grid(True, color='w', linestyle='-', linewidth=.2)
#plt.gca().patch.set_facecolor('0.85')

#plt.xlim(-10,100)
#plt.ylim(-10,10)

plt.xticks(np.arange(min(x5), max(x5)+1, 1.0))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-aff3108a3087> in <module>()
#      13 #plt.ylim(-10,10)
#      14
# ---> 15 plt.xticks(np.arange(min(x5), max(x5)+1, 1.0))
#      16
#      17 plt.show()
#
# TypeError: must be str, not int

# %%
correlation = desert_csv_df.groupby('State')[['Limited Access Population% 2009','Adult Obsesity % 2009']].corr()
correlation.to_csv('correlation_access_obesity.csv')

# %%
desert_csv_df.head()

outlier = desert_csv_df.groupby('State').mean()

outlier.reset_index(inplace = True)


outlier_df = outlier[['State', '% Change in Obesity', '% change in Access']]

outlier_df.head()
# Out:
#   State  % Change in Obesity  % change in Access
# 0    AK            -3.868000           13.310000
# 1    AL             3.277424           29.911364
# 2    AR             7.626197           41.280000
# 3    AZ             3.651538            7.690769
# 4    CA            -1.526136           -3.377500

# %%
outlier_df['outlier'] = outlier_df.apply((lambda x: (x[2]> 0 and x[1]>0) or (x[2]< 0 and x[1]<0)  ), axis = 1) 

outlier_df
# Out:
# C:\Users\John Jenkins\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    State  % Change in Obesity  % change in Access  outlier
# 0     AK            -3.868000           13.310000    False
# 1     AL             3.277424           29.911364     True
# 2     AR             7.626197           41.280000     True
# 3     AZ             3.651538            7.690769     True
# 4     CA            -1.526136           -3.377500     True
# 5     CO             2.454821            0.107857     True
# 6     CT             9.686667           -1.623333    False
# 7     DE             2.875000          -16.720000    False
# 8     FL             1.528387            1.470645     True
# 9     GA             3.035032           11.940000     True
# 10    HI            -6.432000           -0.680000     True
# 11    IA             7.015699            7.987419     True
# 12    ID             3.266829            7.023902     True
# 13    IL             2.969388           12.256735     True
# 14    IN             2.894444           17.023333     True
# 15    KS             2.179143           17.597143     True
# 16    KY             3.127667            8.949000     True
# 17    LA             5.148409           -0.480227    False
# 18    MA             0.770714          -13.382143    False
# 19    MD             5.185500           31.884500     True
# 20    ME             0.627500           -5.960625    False
# 21    MI             1.425897           11.492692     True
# 22    MN             3.579737           -4.340658    False
# 23    MO             2.980280           16.569252     True
# 24    MS             3.646500           14.666875     True
# 25    MT             3.967708            6.884167     True
# 26    NC             2.272828            0.623838     True
# 27    ND             3.401961          -10.590784    False
# 28    NE             2.488539           -7.723483    False
# 29    NH             8.821000           -6.348000    False
# 30    NJ             4.055000            1.925500     True
# 31    NM             2.231154            1.256923     True
# 32    NV             2.417333           16.272000     True
# 33    NY             1.768667            5.523833     True
# 34    OH             3.251954           15.274023     True
# 35    OK             5.207200           18.485200     True
# 36    OR             4.766286            0.976857     True
# 37    PA             3.513731            5.342985     True
# 38    RI             3.892000          -15.734000    False
# 39    SC             2.070870           31.387174     True
# 40    SD            -0.639365           -0.918730     True
# 41    TN             2.359043           -0.652766    False
# 42    TX            -1.059705           17.321646    False
# 43    UT            -0.320385          -11.589615     True
# 44    VA             1.418700            2.987300     True
# 45    VT             3.164615           -3.643846    False
# 46    WA             2.524571           20.446857     True
# 47    WI             3.060303           12.537879     True
# 48    WV             3.552364           24.310364     True
# 49    WY             3.260000           -0.268571    False

# %%
x = outlier_df['% Change in Obesity']
y = outlier_df['% change in Access']

outlier_df['outlier']=

outlier_df
# Out:
#   File "<ipython-input-122-0dc5e7c52a13>", line 4
#     outlier_df['outlier']= (if x >0 and y >0)
#                              ^
# SyntaxError: invalid syntax

# %%
for x in range():
    print(outlier_df.iloc[0,x])
# Out:
# AK
# -3.868
# 13.31

# %%
outliers = []

for state in outlier_df.iterrows():
    if state [0] > 0:
        print(state)
# Out:
# (1, State                       AL
# % Change in Obesity    3.27742
# % change in Access     29.9114
# Name: 1, dtype: object)
# (2, State                      AR
# % Change in Obesity    7.6262
# % change in Access      41.28
# Name: 2, dtype: object)
# (3, State                       AZ
# % Change in Obesity    3.65154
# % change in Access     7.69077
# Name: 3, dtype: object)
# (4, State                       CA
# % Change in Obesity   -1.52614
# % change in Access     -3.3775
# Name: 4, dtype: object)
# (5, State                        CO
# % Change in Obesity     2.45482
# % change in Access     0.107857
# Name: 5, dtype: object)
# (6, State                       CT
# % Change in Obesity    9.68667
# % change in Access    -1.62333
# Name: 6, dtype: object)
# (7, State                     DE
# % Change in Obesity    2.875
# % change in Access    -16.72
# Name: 7, dtype: object)
# (8, State                       FL
# % Change in Obesity    1.52839
# % change in Access     1.47065
# Name: 8, dtype: object)
# (9, State                       GA
# % Change in Obesity    3.03503
# % change in Access       11.94
# Name: 9, dtype: object)
# (10, State                     HI
# % Change in Obesity   -6.432
# % change in Access     -0.68
# Name: 10, dtype: object)
# (11, State                       IA
# % Change in Obesity     7.0157
# % change in Access     7.98742
# Name: 11, dtype: object)
# (12, State                       ID
# % Change in Obesity    3.26683
# % change in Access      7.0239
# Name: 12, dtype: object)
# (13, State                       IL
# % Change in Obesity    2.96939
# % change in Access     12.2567
# Name: 13, dtype: object)
# (14, State                       IN
# % Change in Obesity    2.89444
# % change in Access     17.0233
# Name: 14, dtype: object)
# (15, State                       KS
# % Change in Obesity    2.17914
# % change in Access     17.5971
# Name: 15, dtype: object)
# (16, State                       KY
# % Change in Obesity    3.12767
# % change in Access       8.949
# Name: 16, dtype: object)
# (17, State                        LA
# % Change in Obesity     5.14841
# % change in Access    -0.480227
# Name: 17, dtype: object)
# (18, State                        MA
# % Change in Obesity    0.770714
# % change in Access     -13.3821
# Name: 18, dtype: object)
# (19, State                       MD
# % Change in Obesity     5.1855
# % change in Access     31.8845
# Name: 19, dtype: object)
# (20, State                       ME
# % Change in Obesity     0.6275
# % change in Access    -5.96062
# Name: 20, dtype: object)
# (21, State                       MI
# % Change in Obesity     1.4259
# % change in Access     11.4927
# Name: 21, dtype: object)
# (22, State                       MN
# % Change in Obesity    3.57974
# % change in Access    -4.34066
# Name: 22, dtype: object)
# (23, State                       MO
# % Change in Obesity    2.98028
# % change in Access     16.5693
# Name: 23, dtype: object)
# (24, State                       MS
# % Change in Obesity     3.6465
# % change in Access     14.6669
# Name: 24, dtype: object)
# (25, State                       MT
# % Change in Obesity    3.96771
# % change in Access     6.88417
# Name: 25, dtype: object)
# (26, State                        NC
# % Change in Obesity     2.27283
# % change in Access     0.623838
# Name: 26, dtype: object)
# (27, State                       ND
# % Change in Obesity    3.40196
# % change in Access    -10.5908
# Name: 27, dtype: object)
# (28, State                       NE
# % Change in Obesity    2.48854
# % change in Access    -7.72348
# Name: 28, dtype: object)
# (29, State                     NH
# % Change in Obesity    8.821
# % change in Access    -6.348
# Name: 29, dtype: object)
# (30, State                      NJ
# % Change in Obesity     4.055
# % change in Access     1.9255
# Name: 30, dtype: object)
# (31, State                       NM
# % Change in Obesity    2.23115
# % change in Access     1.25692
# Name: 31, dtype: object)
# (32, State                       NV
# % Change in Obesity    2.41733
# % change in Access      16.272
# Name: 32, dtype: object)
# (33, State                       NY
# % Change in Obesity    1.76867
# % change in Access     5.52383
# Name: 33, dtype: object)
# (34, State                       OH
# % Change in Obesity    3.25195
# % change in Access      15.274
# Name: 34, dtype: object)
# (35, State                       OK
# % Change in Obesity     5.2072
# % change in Access     18.4852
# Name: 35, dtype: object)
# (36, State                        OR
# % Change in Obesity     4.76629
# % change in Access     0.976857
# Name: 36, dtype: object)
# (37, State                       PA
# % Change in Obesity    3.51373
# % change in Access     5.34299
# Name: 37, dtype: object)
# (38, State                      RI
# % Change in Obesity     3.892
# % change in Access    -15.734
# Name: 38, dtype: object)
# (39, State                       SC
# % Change in Obesity    2.07087
# % change in Access     31.3872
# Name: 39, dtype: object)
# (40, State                        SD
# % Change in Obesity   -0.639365
# % change in Access     -0.91873
# Name: 40, dtype: object)
# (41, State                        TN
# % Change in Obesity     2.35904
# % change in Access    -0.652766
# Name: 41, dtype: object)
# (42, State                       TX
# % Change in Obesity    -1.0597
# % change in Access     17.3216
# Name: 42, dtype: object)
# (43, State                        UT
# % Change in Obesity   -0.320385
# % change in Access     -11.5896
# Name: 43, dtype: object)
# (44, State                      VA
# % Change in Obesity    1.4187
# % change in Access     2.9873
# Name: 44, dtype: object)
# (45, State                       VT
# % Change in Obesity    3.16462
# % change in Access    -3.64385
# Name: 45, dtype: object)
# (46, State                       WA
# % Change in Obesity    2.52457
# % change in Access     20.4469
# Name: 46, dtype: object)
# (47, State                       WI
# % Change in Obesity     3.0603
# % change in Access     12.5379
# Name: 47, dtype: object)
# (48, State                       WV
# % Change in Obesity    3.55236
# % change in Access     24.3104
# Name: 48, dtype: object)
# (49, State                        WY
# % Change in Obesity        3.26
# % change in Access    -0.268571
# Name: 49, dtype: object)

# %%
#outlier_df[['State','% Change in Obesity', '% change in Access']]

xed = outlier_df['% Change in Obesity']
yed = outlier_df['% change in Access']

x_list = [x for x in outlier_df if x>0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-9e3cd5e021eb> in <module>()
#       5 yed = outlier_df['% change in Access']
#       6
# ----> 7 x_list = [x for x in outlier_df if x>0]
#       8
#       9
#
# <ipython-input-103-9e3cd5e021eb> in <listcomp>(.0)
#       5 yed = outlier_df['% change in Access']
#       6
# ----> 7 x_list = [x for x in outlier_df if x>0]
#       8
#       9
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
for state in outlier_df:
    if '% Change in Obesity' > 0 and '% change in Access' < 0:
        print('outlier')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-12ee8370b492> in <module>()
#       1 for state in outlier_df:
# ----> 2     if '% Change in Obesity' > 0 and '% change in Access' < 0:
#       3         print('outlier')
#
# TypeError: '>' not supported between instances of 'str' and 'int'
