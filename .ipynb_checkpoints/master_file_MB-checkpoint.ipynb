# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from scipy.stats import linregress
import seaborn as sns

# %%
desert_csv = "Food Desert_Data_jj.csv"

# %%
desert_csv_df = pd.read_csv(desert_csv)

# %%
desert_csv_df.head()
# Out:
#   State   Region            Division County Name  Grocery 2009  \
# 0    AL    South  East South Central       Coosa             0
# 1    AK     West             Pacific  Dillingham             5
# 2    CO     West            Mountain     Mineral             1
# 3    GA    South      South Atlantic       Irwin             1
# 4    IA  Midwest  West North Central     Audubon             2
#
#    Convenience 2009  Fast Food Restaurants 2009  Adult Diabetes % 2009  \
# 0                 9                           0                   15.1
# 1                 2                           0                    8.2
# 2                 0                           0                    6.9
# 3                 6                           0                   11.7
# 4                 3                           0                   10.4
#
#    Adult Obsesity % 2009  Median Household Income 2009         ...          \
# 0                   33.8                         33721         ...
# ...

# %%
desert_csv_df.plot.scatter("Grocery 2009", "Fast Food Restaurants 2009", s=2, c= "blue")
plt.show()

# %%
desert_csv_df.plot.scatter("Median Household Income 2009", "Fast Food Restaurants 2009", s=2, c= "blue")
plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
new_csv = "Food Desert_Data_jj.csv"

# %%
new_csv_df = pd.read_csv(new_csv)
new_csv_df.head()
# Out:
#   State   Region            Division County Name  Grocery 2009  \
# 0    AL    South  East South Central       Coosa             0
# 1    AK     West             Pacific  Dillingham             5
# 2    CO     West            Mountain     Mineral             1
# 3    GA    South      South Atlantic       Irwin             1
# 4    IA  Midwest  West North Central     Audubon             2
#
#    Convenience 2009  Fast Food Restaurants 2009  Adult Diabetes % 2009  \
# 0                 9                           0                   15.1
# 1                 2                           0                    8.2
# 2                 0                           0                    6.9
# 3                 6                           0                   11.7
# 4                 3                           0                   10.4
#
#    Adult Obsesity % 2009  Median Household Income 2009         ...          \
# 0                   33.8                         33721         ...
# ...

# %%
desert_csv_df.plot.scatter("Limited Access Population 2009", "Fast Food Restaurants 2009", s=2, c= "blue")
plt.xlim(0,100000)
plt.ylim(-50,800)
plt.grid(True, color='w', linestyle='-', linewidth=.5)
plt.gca().patch.set_facecolor('0.8')

plt.show()

# %%
desert_csv_df.plot.scatter("Limited Access Population 2009", "Grocery 2009", s=2, c= "blue")
plt.xlim(0,100000)
plt.ylim(-10,100)
plt.grid(True, color='w', linestyle='-', linewidth=.5)
plt.gca().patch.set_facecolor('0.8')

plt.show()

# %%
GA_data = desert_csv_df[desert_csv_df['State']=='GA']
GA_data.head()
# Out:
#     State Region        Division    County Name  Grocery 2009  \
# 3      GA  South  South Atlantic          Irwin             1
# 62     GA  South  South Atlantic        Lincoln             1
# 88     GA  South  South Atlantic         Elbert             1
# 151    GA  South  South Atlantic  Chattahoochee             1
# 178    GA  South  South Atlantic        Lumpkin             2
#
#      Convenience 2009  Fast Food Restaurants 2009  Adult Diabetes % 2009  \
# 3                   6                           0                   11.7
# 62                  6                           2                   10.5
# 88                  4                           3                    4.9
# 151                 1                           1                    6.9
# 178                16                          16                    8.9
#
#      Adult Obsesity % 2009  Median Household Income 2009         ...          \
# 3                     31.2                         32859         ...
# ...

# %%
MT_data = desert_csv_df[desert_csv_df['State']=='MT']
MT_data.head()
# Out:
#     State Region  Division County Name  Grocery 2009  Convenience 2009  \
# 14     MT   West  Mountain     Mineral             1                 0
# 72     MT   West  Mountain     Lincoln             1                 6
# 206    MT   West  Mountain      Carbon             3                 3
# 264    MT   West  Mountain  Stillwater             3                 6
# 309    MT   West  Mountain      Fallon             1                 3
#
#      Fast Food Restaurants 2009  Adult Diabetes % 2009  Adult Obsesity % 2009  \
# 14                            0                    6.9                   19.0
# 72                            2                   10.5                   36.2
# 206                           5                    7.6                   27.2
# 264                           2                    7.7                   27.0
# 309                           2                    7.9                   25.2
#
# ...

# %%
GA_data.plot.scatter("Limited Access Population 2009", "Median Household Income 2009", s=2, c= "blue")
plt.xlim(0,70000)
plt.ylim(0,100000)
plt.grid(True, color='w', linestyle='-', linewidth=.5)
plt.gca().patch.set_facecolor('0.8')


plt.show()

# %%
MT_data.plot.scatter("Limited Access Population 2009", "Median Household Income 2009", s=2, c= "blue")
plt.xlim(0,30000)
plt.ylim(0,80000)
plt.grid(True, color='w', linestyle='-', linewidth=.5)
plt.gca().patch.set_facecolor('0.8')


plt.show()

# %%
GA_data.plot.scatter("Adult Diabetes % 2009", "Median Household Income 2009", s=2, c= "blue")
plt.xlim(0,50)
plt.ylim(0,80000)
plt.grid(True, color='w', linestyle='-', linewidth=.5)
plt.gca().patch.set_facecolor('0.8')


plt.show()

# %%
MT_data.plot.scatter("Adult Diabetes % 2009", "Median Household Income 2009", s=2, c= "blue")
plt.xlim(0,50)
plt.ylim(0,80000)
plt.grid(True, color='w', linestyle='-', linewidth=.5)
plt.gca().patch.set_facecolor('0.8')


plt.show()

# %%
MA_data = desert_csv_df[desert_csv_df['State']=='MA']

# %%
#obesity vs incomce 2009
fig, ax1 = plt.subplots()
x1 = MT_data['Adult Obsesity % 2009']
y1 = MT_data['Median Household Income 2009']
x2 = GA_data['Adult Obsesity % 2009']
y2 = GA_data['Median Household Income 2009']
x3 = MA_data['Adult Obsesity % 2009']
y3 = MA_data['Median Household Income 2009']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT(Standard)")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA(Standard)")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA(Outlier)")
ax1.grid(True)

plt.title("Adult Obesity % vs. Median Household Income 2009")
plt.xlabel("Adult Obesity %")
plt.ylabel("Median Household Income")
plt.legend()
plt.show()

# %%
#obesity vs income 2014
fig, ax1 = plt.subplots()
x1 = MT_data['Adult Obesity 2014']
y1 = MT_data['Median Household Income 2014']
x2 = GA_data['Adult Obesity 2014']
y2 = GA_data['Median Household Income 2014']
x3 = MA_data['Adult Obesity 2014']
y3 = MA_data['Median Household Income 2014']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT(Standard)")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA(Outlier)")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA(Outlier)")
ax1.grid(True)

plt.title("Adult Obesity % vs. Median Household Income 2014")
plt.xlabel("Adult Obesity %")
plt.ylabel("Median Household Income")
plt.legend()
plt.show()

# %%
#Obesity and limited access 2009
fig, ax1 = plt.subplots()
x1 = MT_data['Adult Obsesity % 2009']
y1 = MT_data['Limited Access Population 2009']
x2 = GA_data['Adult Obsesity % 2009']
y2 = GA_data['Limited Access Population 2009']
x3 = MA_data['Adult Obsesity % 2009']
y3 = MA_data['Limited Access Population 2009']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("Adult Obesity % vs. Limited Access Population 2009")
plt.xlabel("Adult Obesity %")
plt.ylabel("Limited Access Population")
plt.xlim(0,40)
plt.ylim(0,25000)
plt.legend()
plt.show()

# %%
#Obesity and limited access 2014
fig, ax1 = plt.subplots()
x1 = MT_data['Adult Obesity 2014']
y1 = MT_data['Limited Access 2014']
x2 = GA_data['Adult Obesity 2014']
y2 = GA_data['Limited Access 2014']
x3 = MA_data['Adult Obesity 2014']
y3 = MA_data['Limited Access 2014']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("Adult Obesity % vs. Limited Access Population 2014")
plt.xlabel("Adult Obesity %")
plt.ylabel("Limited Access Population")
plt.xlim(0,40)
plt.ylim(0,25000)
plt.legend()
plt.show()

# %%
#income vs limited access 2009
fig, ax1 = plt.subplots()
x1 = MT_data['Median Household Income 2009']
y1 = MT_data['Limited Access Population 2009']
x2 = GA_data['Median Household Income 2009']
y2 = GA_data['Limited Access Population 2009']
x3 = MA_data['Median Household Income 2009']
y3 = MA_data['Limited Access Population 2009']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("Median Household Income vs. Limited Access Population 2009")
plt.xlabel("Median Household Income ")
plt.ylabel("Limited Access Population")
plt.xlim(0,80000)
plt.ylim(0,15000)
plt.legend()
plt.show()

# %%
#income vs limited access 2014
fig, ax1 = plt.subplots()
x1 = MT_data['Median Household Income 2014']
y1 = MT_data['Limited Access 2014']
x2 = GA_data['Median Household Income 2014']
y2 = GA_data['Limited Access 2014']
x3 = MA_data['Median Household Income 2014']
y3 = MA_data['Limited Access 2014']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("Median Household Income vs. Limited Access Population 2014")
plt.xlabel("Median Household Income ")
plt.ylabel("Limited Access Population")
plt.xlim(0,80000)
plt.ylim(0,15000)
plt.legend()
plt.show()

# %%
#Income vs Grocery store count 2009
fig, ax1 = plt.subplots()
x1 = MT_data['Median Household Income 2009']
y1 = MT_data['Grocery 2009']
x2 = GA_data['Median Household Income 2009']
y2 = GA_data['Grocery 2009']
x3 = MA_data['Median Household Income 2009']
y3 = MA_data['Grocery 2009']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("Median Household Income vs. Grocery Store Count 2009")
plt.xlabel("Median Household Income ")
plt.ylabel("Grocery Store Count")
plt.xlim(0,75000)
plt.ylim(0,35)
plt.legend()
plt.show()

# %%
#Income vs FFR count 2009
fig, ax1 = plt.subplots()
x1 = MT_data['Median Household Income 2009']
y1 = MT_data['Fast Food Restaurants 2009']
x2 = GA_data['Median Household Income 2009']
y2 = GA_data['Fast Food Restaurants 2009']
x3 = MA_data['Median Household Income 2009']
y3 = MA_data['Fast Food Restaurants 2009']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("Median Household Income vs. Fast Food Restaurants 2009")
plt.xlabel("Median Household Income ")
plt.ylabel("FFR Count")
plt.xlim(0,75000)
plt.ylim(0,35)
plt.legend()
plt.show()

# %%
#Obesity vs Grocery count
fig, ax1 = plt.subplots()
x1 = MT_data['Adult Obsesity % 2009']
y1 = MT_data['Grocery 2009']
x2 = GA_data['Adult Obsesity % 2009']
y2 = GA_data['Grocery 2009']
x3 = MA_data['Adult Obsesity % 2009']
y3 = MA_data['Grocery 2009']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("Adult Obesity % vs. Grocery Store Count 2009")
plt.xlabel("Adult Obesity %")
plt.ylabel("Grocery Count")
plt.xlim(0,50)
plt.ylim(0,150)
plt.legend()
plt.show()

# %%
#Obesity vs FFR Count 2009
fig, ax1 = plt.subplots()
x1 = MT_data['Adult Obsesity % 2009']
y1 = MT_data['Fast Food Restaurants 2009']
x2 = GA_data['Adult Obsesity % 2009']
y2 = GA_data['Fast Food Restaurants 2009']
x3 = MA_data['Adult Obsesity % 2009']
y3 = MA_data['Fast Food Restaurants 2009']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("Adult Obesity % vs. Fast Food Restaurants Count 2009")
plt.xlabel("Adult Obesity %")
plt.ylabel("FFR Count")
plt.xlim(-10,50)
plt.ylim(-10,150)
plt.legend()
plt.show()

# %%
#% in access vs % change in obesity 
fig, ax1 = plt.subplots()
x1 = MT_data['% change in Access']
y1 = MT_data['% Change in Obesity']
x2 = GA_data['% change in Access']
y2 = GA_data['% Change in Obesity']
x3 = MA_data['% change in Access']
y3 = MA_data['% Change in Obesity']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("% Change in Limited Access vs. % Change in Obesity")
plt.xlabel("% Change in Limited Access ")
plt.ylabel("% Change in Obesity")
plt.xlim(-100,100)
plt.ylim(-50,50)
plt.legend()
plt.show()

# %%
#% Change in Access vs % Change in Income 
fig, ax1 = plt.subplots()
x1 = MT_data['% change in Access']
y1 = MT_data['% change in income']
x2 = GA_data['% change in Access']
y2 = GA_data['% change in income']
x3 = MA_data['% change in Access']
y3 = MA_data['% change in income']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("% Change in Limited Access vs. % Change in Income")
plt.xlabel("% Change in Limited Access ")
plt.ylabel("% Change in Income")
plt.xlim(-100,100)
plt.ylim(-20,50)
plt.legend()
plt.show()

# %%
#% change in Obesity vs % change in Income
fig, ax1 = plt.subplots()
x1 = MT_data['% change in income']
y1 = MT_data['% Change in Obesity']
x2 = GA_data['% change in income']
y2 = GA_data['% Change in Obesity']
x3 = MA_data['% change in income']
y3 = MA_data['% Change in Obesity']

ax1.scatter(x1,y1, c= "blue", alpha=0.4, label = "MT")
ax1.scatter(x2,y2, c= "lime", alpha=0.4, label = "GA")
ax1.scatter(x3,y3, c= "red", alpha=0.4, label = "MA")
ax1.grid(True)

plt.title("% change in Income vs. % Change in Obesity")
plt.xlabel("% Change in Income ")
plt.ylabel("% Change in Obesity")
plt.xlim(-50,50)
plt.ylim(-50,50)
plt.legend()
plt.show()

# %%
#diabetes to income
#diabetes to limited acccess
#income to limited Access
#income to store ocount
#income to FFR
